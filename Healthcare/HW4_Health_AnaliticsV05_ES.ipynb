# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\escag\es_repo280720\Homework\Unit4\Health_Analitics_II\healthcare\train_data.csv')

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
df.describe()
# Out:
#              case_id  Hospital_code  City_Code_Hospital  \
# count  318438.000000  318438.000000       318438.000000
# mean   159219.500000      18.318841            4.771717
# std     91925.276847       8.633755            3.102535
# min         1.000000       1.000000            1.000000
# 25%     79610.250000      11.000000            2.000000
# 50%    159219.500000      19.000000            5.000000
# 75%    238828.750000      26.000000            7.000000
# max    318438.000000      32.000000           13.000000
#
#        Available Extra Rooms in Hospital      Bed Grade      patientid  \
# count                      318438.000000  318325.000000  318438.000000
# mean                            3.197627       2.625807   65747.579472
# std                             1.168171       0.873146   37979.936440
# min                             0.000000       1.000000       1.000000
# 25%                             2.000000       2.000000   32847.000000
# ...

# %%
import numpy as np

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['case_id', 'Hospital_code', 'City_Code_Hospital',
#        'Available Extra Rooms in Hospital', 'Bed Grade', 'patientid',
#        'City_Code_Patient', 'Visitors with Patient', 'Admission_Deposit'],
#       dtype='object')

# %%
df.select_dtypes(exclude=np.number).columns
# Out:
# Index(['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type',
#        'Ward_Facility_Code', 'Type of Admission', 'Severity of Illness', 'Age',
#        'Stay'],
#       dtype='object')

# %%
dict1b={'case_id': np.int32, 'Hospital_code': np.int8, 'City_Code_Hospital': np.int8,
       'Available Extra Rooms in Hospital': np.int8, 'Bed Grade': np.float32, 'patientid': np.int32,
       'City_Code_Patient': np.float32, 'Visitors with Patient': np.int8, 'Admission_Deposit': np.float32,
      }

# %%
df=pd.read_csv(r'C:\Users\escag\es_repo280720\Homework\Unit4\Health_Analitics_II\healthcare\train_data.csv', dtype=dict1b)

# %%
df.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
#df['Bed Grade'].fillna(-1, inplace=True)
#df['City_Code_Patient'].fillna(-1, inplace=True)

# %%
df[['Stay']]
# Out:
#          Stay
# 0        0-10
# 1       41-50
# 2       31-40
# 3       41-50
# 4       41-50
# ...       ...
# 318433  11-20
# 318434  31-40
# 318435  11-20
# 318436  11-20
# 318437   0-10
#
# [318438 rows x 1 columns]

# %%
age_bins=['0-10','11-20','21-30', '31-40','41-50', '51-60', '61-70','71-80', '81-90', '91-100']

# %%
df.Stay.unique()
# Out:
# array(['0-10', '41-50', '31-40', '11-20', '51-60', '21-30', '71-80',
#        'More than 100 Days', '81-90', '61-70', '91-100'], dtype=object)

# %%
df.Stay.replace('More than 100 Days', '>100', inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dict_stay={'0-10':1, '41-50': 5, '31-40': 4, '11-20': 2, '51-60': 6, '21-30' : 3, '71-80': 8, '>100': 11, '81-90' : 9, '61-70': 7, '91-100': 10}
df['Stay_int']=df.Stay.copy().replace(dict_stay)
df.Stay_int=df.Stay_int.astype('int8')

# %%
sns.heatmap(df.corr()); # Best correlation is 'Stay' with 'Visitors with Patient'

# %%
sns.pairplot(df.loc[:,df.dtypes != 'category']) #General Look at relationships between different columns of data

# %%
stay_bins=['0-10','11-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90','91-100', '>100']

# %%
df['Stay'].value_counts()[stay_bins].plot(kind='bar')

# %%
g=sns.catplot(data=df, kind='bar', x='Stay', y='Available Extra Rooms in Hospital', hue='Department', height=6, aspect=2, order=stay_bins,hue_order=['gynecology', 'surgery','radiotherapy', 'TB & Chest disease', 'anesthesia'])

# %%
import matplotlib as mpl
# %matplotlib inline

# %%
sns.catplot(x='Stay', kind='count', col='Severity of Illness', order=stay_bins,data=df)

# %%
sns.catplot(x='Stay', kind='count', col='Bed Grade', col_wrap=2, data=df, order=stay_bins,hue='Severity of Illness')

# %%
sns.catplot(x='Stay', kind='count', col='Severity of Illness', order=stay_bins,data=df)

# %%
#f, axes = plt.subplots(3, 2, figsize=(15, 15))
sns.catplot(x='Stay', kind='count', col='Department',order=stay_bins, col_wrap=2, data=df, height=4, aspect=1.2, sharey=False,sharex=False)

# %%
df['Type of Admission'].unique()
# Out:
# array(['Emergency', 'Trauma', 'Urgent'], dtype=object)

# %%
sns.catplot(x='Stay', kind='count', hue='Type of Admission', order=stay_bins,data=df, aspect=1.5)

# %%
df['Age'].unique()
# Out:
# array(['51-60', '71-80', '31-40', '41-50', '81-90', '61-70', '21-30',
#        '11-20', '0-10', '91-100'], dtype=object)

# %%
sns.catplot(x='Age', kind='count', order=age_bins, hue='Type of Admission', data=df, aspect=1.5)

# %%
sns.catplot(hue='Age', hue_order=age_bins, kind='count', x='Type of Admission', data=df, aspect=1.5)

# %%
sns.catplot(x='Age', kind='count', hue='Stay',order=age_bins, data=df, height=5,aspect=2.5)

# %%
df['Hospital_code'].unique()
# Out:
# array([ 8,  2, 10, 26, 23, 32,  1, 22, 16,  9,  6, 29, 12,  3, 21, 28, 27,
#        19,  5, 14, 13, 31, 24, 17, 25, 15, 11, 30, 18,  4,  7, 20],
#       dtype=int8)

# %%
grid = sns.FacetGrid(df, col="Stay", hue="Stay", palette="tab20c",
                     col_wrap=4, height=4, aspect=1)
grid.map(plt.hist, 'Hospital_code', bins=32)

# %%
grid = sns.FacetGrid(df, col="Hospital_code", hue="Hospital_code", palette="tab20c",
                     col_wrap=4, height=3, aspect=1.5)
grid.map(plt.hist, 'Stay', bins=11)

# %%
sns.scatterplot(x='Stay_int', y='Visitors with Patient', data=df,hue='Severity of Illness')

# %%
sns.scatterplot(x='Stay_int', y='Visitors with Patient', data=df,hue='Department')

# %%
#Hospital Region Codes
f, axes = plt.subplots(3, 1, sharex=True, sharey=True, figsize=(10, 8))

RC_Z = df[df['Hospital_region_code'] =='Z']["Stay"].value_counts().rename('Count')
sns.barplot(RC_Z.index, RC_Z,  color="b", ax=axes[0]).set_title('Hospital_region_code : Z')

RC_Y = df[df['Hospital_region_code'] =='Y']["Stay"].value_counts().rename('Count')
sns.barplot(RC_Y.index, RC_Y,  color="r", ax=axes[2]).set_title('Hospital_region_code : Y')

RC_X = df[df['Hospital_region_code'] =='X']["Stay"].value_counts().rename('Count')
sns.barplot(RC_X.index, RC_X,  color="y", ax=axes[1]).set_title('Hospital_region_code : X')
# Out:
# Text(0.5, 1.0, 'Hospital_region_code : X')

# %%
import xgboost as xgb
from sklearn.ensemble import GradientBoostingClassifier
import category_encoders as ce
from utils import extract_dates, get_val_scores
from category_encoders import OrdinalEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection  import RepeatedStratifiedKFold

# %%
mod1 = xgb.XGBClassifier()

# %%
pipe = make_pipeline(OrdinalEncoder(), mod1)
X = df.drop(['Stay', 'case_id', 'Stay_int'], axis=1)
y = df['Stay']

# %%
#X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.20, random_state=65)
cv=RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)

# %%
pipe.steps[1][1].set_params(max_depth=3,objective='multi:softmax',learning_rate=0.1, n_estimators=100,scale_pos_weight=None)
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softmax', random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method=None, validate_parameters=None, verbosity=None)

# %%
#Additional parameters  for Multiclass evaluation
pipe.steps[1][1].set_params(num_class=11, eval_metric='merror')
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               eval_metric='merror', gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_class=11,
#               num_parallel_tree=None, objective='multi:softmax',
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)

# %%
scores = get_val_scores(pipe, X, y, return_test_score=True,  random_state=65, use_kfold=True,return_folds=True, cv=cv)

# %%
scores
# Out:
# {'validation_score': 0.40691396794242723,
#  'fold_scores': array([0.41293425, 0.40368989, 0.40761531, 0.41022571, 0.40288518,
#         0.41417076, 0.40488714, 0.40533857, 0.40480864, 0.40582924,
#         0.40633955, 0.40457311, 0.40749755, 0.40675172, 0.4061629 ]),
#  'test_score': 0.4065915086044467}

# %%
feats = pd.DataFrame({ 'Importance': pipe.steps[1][1].feature_importances_, 'Column': X.columns})
feats.sort_values(by='Importance', ascending=False)
# Out:
#     Importance                             Column
# 13    0.231428              Visitors with Patient
# 11    0.148724                  Type of Admission
# 4     0.099005  Available Extra Rooms in Hospital
# 8     0.094291                          Bed Grade
# 6     0.086628                          Ward_Type
# 3     0.068792               Hospital_region_code
# 7     0.047302                 Ward_Facility_Code
# 12    0.044923                Severity of Illness
# 0     0.031420                      Hospital_code
# 15    0.030837                  Admission_Deposit
# 2     0.026861                 City_Code_Hospital
# 10    0.025294                  City_Code_Patient
# 1     0.020409                 Hospital_type_code
# 14    0.020139                                Age
# 5     0.019550                         Department
# 9     0.004396                          patientid

# %% [markdown]
# ## Feature Engineering

# %%
#Calculate count fraction for each 'Stay' class. Unbalanced classes
for days in stay_bins:
    count_stay=df[df.Stay==days]['Stay'].count()
    print(days, " ", "{:.2f}".format( 100*count_stay/df.shape[0]))
# Out:
# 0-10   7.41
# 11-20   24.54
# 21-30   27.48
# 31-40   17.32
# 41-50   3.69
# 51-60   11.00
# 61-70   0.86
# 71-80   3.22
# 81-90   1.52
# 91-100   0.87
# >100   2.10

# %%
#Visitors with patient: +ve correlation with Stay
VwP_avg=df.groupby('Stay')[['Visitors with Patient']].mean().reset_index().rename({'Visitors with Patient': 'VwP_avg'}, axis=1)
VwP_avg
# Out:
#       Stay   VwP_avg
# 0     0-10  2.565158
# 1    11-20  2.738940
# 2    21-30  2.679487
# 3    31-40  3.453797
# 4    41-50  3.032785
# 5    51-60  4.390828
# 6    61-70  3.566691
# 7    71-80  4.892335
# 8    81-90  6.100661
# 9   91-100  5.315732
# 10    >100  7.891516

# %%
#from scipy.stats.mstats import mode

# %%
df['Visitors with Patient'].unique()
# Out:
# array([ 2,  4,  3,  8,  6,  7, 13,  5,  1, 10, 15, 11, 12,  9, 24, 16, 14,
#        20,  0, 19, 18, 17, 23, 21, 32, 30, 22, 25], dtype=int8)

# %%
sns.boxenplot(x='Bed Grade', y='Visitors with Patient',scale='area', data=df)

# %%
sns.boxenplot(x='Department', y='Visitors with Patient',scale='area', data=df)
#sns.scatterplot(x='Department', y='Visitors with Patient', data=df)

# %%
BG_avgVwP=df.groupby('Bed Grade')[['Visitors with Patient']].mean().reset_index().rename({'Visitors with Patient': 'BGVwP_avg'}, axis=1)

# %%
df=df.merge(BG_avgVwP, on='Bed Grade')
df['BG_avgVwP_pct']=df['Visitors with Patient']/df['BGVwP_avg']

# %%
BG_avgVwP ## averages are quite close, probably wont help
# Out:
#    Bed Grade  BGVwP_avg
# 0        1.0   3.287644
# 1        2.0   3.044918
# 2        3.0   3.422343
# 3        4.0   3.531043

# %%
SIll_avgVwP=df.groupby('Severity of Illness')[['Visitors with Patient']].mean().reset_index().rename({'Visitors with Patient': 'SIllVwP_avg'}, axis=1)

# %%
SIll_avgVwP ## averages are quite close, probably wont help
# Out:
#   Severity of Illness  SIllVwP_avg
# 0             Extreme     3.440210
# 1               Minor     3.182202
# 2            Moderate     3.283623

# %%
df=df.merge(SIll_avgVwP, on='Severity of Illness')
df['SIllVwP_avg_pct']=df['Visitors with Patient']/df['SIllVwP_avg']

# %%
Dpt_avgVwP=df.groupby('Department')[['Visitors with Patient']].mean().reset_index().rename({'Visitors with Patient': 'DptVwP_avg'}, axis=1)
df=df.merge(Dpt_avgVwP, on='Department')
df['Dpt_avgVwP_pct']=df['Visitors with Patient']/df['DptVwP_avg']
df['Dpt_avgVwP_pct']=df['Visitors with Patient']/df['DptVwP_avg']

# %%
Dpt_avgVwP ## averages are quite close, probably wont help
# Out:
#            Department  DptVwP_avg
# 0  TB & Chest disease    3.350376
# 1          anesthesia    3.091544
# 2          gynecology    3.291659
# 3        radiotherapy    3.376587
# 4             surgery    3.757702

# %%
for dpt in list(df.Department.unique()):
    query=df['Department']==dpt
    countdpt=df.loc[query]['Visitors with Patient'].count()
    print(dpt, " ", countdpt)
# Out:
# radiotherapy   28506
# anesthesia   29647
# gynecology   249387
# TB & Chest disease   9584
# surgery   1201

# %%
mod1 = xgb.XGBClassifier()

# %%
pipe = make_pipeline(OrdinalEncoder(), mod1)
X = df.drop(['Stay', 'case_id', 'Stay_int'], axis=1)
y = df['Stay']

# %%
#X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.20, random_state=65)
cv=RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)

# %%
pipe.steps[1][1].set_params(max_depth=3,objective='multi:softmax',learning_rate=0.1, n_estimators=100,scale_pos_weight=None)
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softmax', random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=None,
#               tree_method=None, validate_parameters=None, verbosity=None)

# %%
#Additional parameters  for Multiclass evaluation
pipe.steps[1][1].set_params(num_class=11, eval_metric='merror')
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               eval_metric='merror', gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=None, max_depth=3,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_class=11,
#               num_parallel_tree=None, objective='multi:softmax',
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)

# %%
scores = get_val_scores(pipe, X, y, return_test_score=True,  random_state=65, use_kfold=True,return_folds=True, cv=cv)

# %%
scores
# Out:
# {'validation_score': 0.4052972590905521,
#  'fold_scores': array([0.40357732, 0.40556035, 0.40493207, 0.40532475, 0.40265452,
#         0.40677766, 0.40893741, 0.40428414, 0.40499097, 0.40569779,
#         0.40644389, 0.40540328, 0.40762193, 0.40133904, 0.40591377]),
#  'test_score': 0.40582737768004395}

# %%
#New columns dont help, as expected. Remove them
df.columns
df.drop(['BGVwP_avg', 'BG_avgVwP_pct',
       'SIllVwP_avg', 'SIllVwP_avg_pct', 'DptVwP_avg', 'Dpt_avgVwP_pct'], axis =1 , inplace=True)

# %% [markdown]
# ## Add Weights

# %%
X = df.drop(['Stay', 'case_id', 'Stay_int'], axis=1)
y = df['Stay']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=65)

# %%
#Adding weights
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight('balanced', np.unique(y_train), 
                                 y_train)

# %%
stay_bins
# Out:
# ['0-10',
#  '11-20',
#  '21-30',
#  '31-40',
#  '41-50',
#  '51-60',
#  '61-70',
#  '71-80',
#  '81-90',
#  '91-100',
#  '>100']

# %%
stay_bins
# Out:
# ['0-10',
#  '11-20',
#  '21-30',
#  '31-40',
#  '41-50',
#  '51-60',
#  '61-70',
#  '71-80',
#  '81-90',
#  '91-100',
#  '>100']

# %%
weight_dict={}
for i in range(len(stay_bins)):
    weight_dict[stay_bins[i]] = class_weights[i]
print(weight_dict)
# Out:
# {'0-10': 1.2264518831271995, '11-20': 0.3704802500214508, '21-30': 0.33087724356851267, '31-40': 0.5248281303757543, '41-50': 2.4653066754408037, '51-60': 0.8266970410898447, '61-70': 10.550838682957133, '71-80': 2.8232464841022686, '81-90': 5.982715295554355, '91-100': 10.46975176722012, '>100': 4.331230766615095}

# %%
sample_weights=y_train

# %%
sample_weights=sample_weights.replace(weight_dict)

# %%
sample_weights=sample_weights.values

# %%
pipe.steps[1][1].set_params(max_depth=3,objective='multi:softmax',learning_rate=0.1, n_estimators=100,scale_pos_weight=None)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_class=11, num_parallel_tree=1, objective='multi:softmax',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
pipe.fit(X_train, y_train, xgbclassifier__sample_weight=sample_weights)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['Hospital_type_code',
#                                       'Hospital_region_code', 'Department',
#                                       'Ward_Type', 'Ward_Facility_Code',
#                                       'Type of Admission',
#                                       'Severity of Illness', 'Age'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'Hospital_type_code',
#                                           'data_type': dtype('O'),
#                                           'mapping': c      1
# a      2
# d      3
# e      4
# b      5
# f...
#                                interaction_constraints='', learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
# ...

# %%
pipe.score(X_test, y_test) ##Doesnt help!
# Out:
# 0.27992714483105136

# %% [markdown]
# ## Parameter Tuning

# %%
X = df.drop(['Stay', 'case_id', 'Stay_int', 'patientid'], axis=1)
y = df['Stay']

# %%
pipe.steps[1][1].set_params(max_depth=3,objective='multi:softmax',learning_rate=0.1, n_estimators=100,scale_pos_weight=None)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_class=11, num_parallel_tree=1, objective='multi:softmax',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
# parameter tuning -- THIS CRASHED OVERNIGHT!!
max_depth = [5, 7]
num_trees = [500, 800]
cv_scores = []
cv=RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)

for depth in max_depth:
    for tree in num_trees:
        print(f"New round.  Depth: {depth}, Trees: {tree}")
        pipe.steps[1][1].set_params(max_depth=depth, n_estimators=tree)
        scores = get_val_scores(pipe, X, y, return_test_score=True, random_state=65, use_kfold=True,return_folds=True, cv=cv)
        print(f"Score after fitting: {scores}")
        cv_scores.append((scores, depth, tree))
# Out:
# New round.  Depth: 5, Trees: 500

# %%
#pipe = make_pipeline(OrdinalEncoder(), mod1)
X = df.drop(['Stay', 'case_id', 'Stay_int', 'patientid'], axis=1)
y = df['Stay']

# %%
#X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.20, random_state=65)
#cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
pipe.steps[1][1].set_params(max_depth=5,objective='multi:softmax',learning_rate=0.1, n_estimators=500,scale_pos_weight=None)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=5, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=500, n_jobs=0,
#               num_class=11, num_parallel_tree=1, objective='multi:softmax',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
scores = get_val_scores(pipe, X, y, return_test_score=True,  random_state=65, use_kfold=False,return_folds=True)

# %%
scores
# Out:
# {'validation_score': 0.4259666339548577, 'test_score': 0.4230310262529833}

# %%
#Fit on ALL of our training set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=65)

# %%
pipe.steps[1]
# Out:
# ('xgbclassifier',
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#                gamma=0, gpu_id=-1, importance_type='gain',
#                interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#                max_depth=5, min_child_weight=1, missing=nan,
#                monotone_constraints='()', n_estimators=500, n_jobs=0,
#                num_class=11, num_parallel_tree=1, objective='multi:softprob',
#                random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#                subsample=1, tree_method='exact', validate_parameters=1,
#                verbosity=None))

# %%
pipe.steps[1][1].set_params(objective='multi:softmax')
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_class=11, num_parallel_tree=1, objective='multi:softmax',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
pipe.fit(X_train,  y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['Hospital_type_code',
#                                       'Hospital_region_code', 'Department',
#                                       'Ward_Type', 'Ward_Facility_Code',
#                                       'Type of Admission',
#                                       'Severity of Illness', 'Age'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value',
#                                 mapping=[{'col': 'Hospital_type_code',
#                                           'data_type': dtype('O'),
#                                           'mapping': a      1
# b      2
# e      3
# c      4
# d      5
# f...
#                                interaction_constraints='', learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
# ...

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4085699032784826

# %%
pipe.steps[1][1].feature_importances_
# Out:
# array([0.02738602, 0.03163867, 0.03150022, 0.03596098, 0.02724881,
#        0.02136317, 0.21786787, 0.0545279 , 0.05150085, 0.02417504,
#        0.10297613, 0.04580786, 0.28873208, 0.01669899, 0.02261538],
#       dtype=float32)

# %%
feats = pd.DataFrame({ 'Importance': pipe.steps[1][1].feature_importances_, 'Column': X.columns})
feats.sort_values(by='Importance', ascending=False)
# Out:
#     Importance                             Column
# 12    0.288732              Visitors with Patient
# 6     0.217868                          Ward_Type
# 10    0.102976                  Type of Admission
# 7     0.054528                 Ward_Facility_Code
# 8     0.051501                          Bed Grade
# 11    0.045808                Severity of Illness
# 3     0.035961               Hospital_region_code
# 1     0.031639                 Hospital_type_code
# 2     0.031500                 City_Code_Hospital
# 0     0.027386                      Hospital_code
# 4     0.027249  Available Extra Rooms in Hospital
# 9     0.024175                  City_Code_Patient
# 14    0.022615                  Admission_Deposit
# 5     0.021363                         Department
# 13    0.016699                                Age

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

plot_confusion_matrix(pipe, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='pred');

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         0-10       0.41      0.16      0.23      4721
#        11-20       0.43      0.50      0.46     15628
#        21-30       0.43      0.67      0.52     17498
#        31-40       0.43      0.22      0.29     11032
#        41-50       0.30      0.00      0.01      2349
#        51-60       0.40      0.50      0.45      7004
#        61-70       0.08      0.00      0.00       549
#        71-80       0.34      0.02      0.05      2051
#        81-90       0.34      0.20      0.26       967
#       91-100       0.48      0.03      0.05       553
#         >100       0.54      0.42      0.47      1336
#
#     accuracy                           0.42     63688
#    macro avg       0.38      0.25      0.25     63688
# weighted avg       0.42      0.42      0.39     63688

# %%
from sklearn.metrics import f1_score

y_true = np.where(y_test == '>100', 1, 0)
y_pred = np.where(pipe.predict(X_test) == '>100', 1, 0)
# f1 score
f1_score(y_true, y_pred)
# Out:
# 0.472620050547599

# %%
pipe.predict(X_test)
# Out:
# array(['11-20', '51-60', '51-60', ..., '51-60', '21-30', '21-30'],
#       dtype=object)

# %%
pipe.predict_proba(X_test)
# Out:
# array([[1.5680943e-02, 4.1175896e-01, 4.0106666e-01, ..., 3.3437394e-04,
#         2.5962549e-04, 9.5828029e-04],
#        [7.7373079e-05, 3.0877257e-02, 1.4124955e-02, ..., 9.4517298e-02,
#         9.7340988e-03, 7.2138548e-02],
#        [1.0958158e-04, 8.7914310e-02, 1.8098759e-02, ..., 7.7278487e-02,
#         8.2886852e-03, 2.9615365e-02],
#        ...,
#        [2.8132135e-03, 8.4030800e-02, 4.9516030e-02, ..., 5.8654244e-03,
#         2.1874813e-02, 1.0418089e-02],
#        [4.3250464e-02, 3.3524486e-01, 3.4056529e-01, ..., 1.5043076e-03,
#         2.2791224e-03, 1.0253371e-03],
#        [6.2862650e-02, 2.0344487e-01, 4.0526175e-01, ..., 5.5694696e-03,
#         3.0789198e-03, 4.9576252e-03]], dtype=float32)

# %%
y_true = np.where(y_test == '11-20', 1, 0)
y_pred = np.where(pipe.predict(X_test) == '11-20', 1, 0)

# %%
f1_score(y_true, y_pred)
# Out:
# 0.46212031674742937

# %%
true_idx= y_true==1
gradient= y_true-pipe.predict_proba(X_test)[:,1]
gradient[true_idx]*10 # change scale_pos_weight to 10
# Out:
# array([6.30429715, 8.4800154 , 7.69836828, ..., 6.28482312, 5.4742372 ,
#        6.64755136])

# %% [markdown]
# ## Heroku App:  https://tranquil-shelf-94635.herokuapp.com/
